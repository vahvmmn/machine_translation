# %% [markdown]
# # Colab FAQ
#
# For some basic overview and features offered in Colab notebooks, check out: [Overview of Colaboratory Features](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
#
# You need to use the colab GPU for this assignmentby selecting:
#
# > **Runtime**   →   **Change runtime type**   →   **Hardware Accelerator: GPU**

# %% [markdown]
# ## Setup PyTorch
# All files are stored at /content/csc421/a3/ folder

# %%
######################################################################
# Setup python environment and change the current working directory
######################################################################
# !pip install torch torchvision
# !pip install Pillow==4.0.0
# %mkdir -p /content/csc421/a3/
# %cd /content/csc421/a3
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python2.7/dist-packages (1.0.1.post2)
# Requirement already satisfied: torchvision in /usr/local/lib/python2.7/dist-packages (0.2.2.post3)
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from torchvision) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python2.7/dist-packages (from torchvision) (1.16.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python2.7/dist-packages (from torchvision) (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python2.7/dist-packages (from pillow>=4.1.1->torchvision) (0.46)
# Collecting Pillow==4.0.0
#   Downloading https://files.pythonhosted.org/packages/89/99/0e3522a9764fe371bf9f7729404b1ef7d9c4fc49cbe5f1761c6e07812345/Pillow-4.0.0-cp27-cp27mu-manylinux1_x86_64.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 4.8MB/s
# Requirement already satisfied: olefile in /usr/local/lib/python2.7/dist-packages (from Pillow==4.0.0) (0.46)
# ERROR: fastai 0.7.0 has requirement torch<0.4, but you'll have torch 1.0.1.post2 which is incompatible.
# ERROR: scikit-image 0.14.2 has requirement pillow>=4.3.0, but you'll have pillow 4.0.0 which is incompatible.
# ERROR: torchvision 0.2.2.post3 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# Installing collected packages: Pillow
#   Found existing installation: Pillow 4.3.0
#     Uninstalling Pillow-4.3.0:
#       Successfully uninstalled Pillow-4.3.0
# Successfully installed Pillow-4.0.0
# /content/csc421/a3

# %% [markdown]
# # Helper code

# %% [markdown]
# ## Utility functions

# %%
import os
import pdb
import argparse
import pickle as pkl

from collections import defaultdict

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

from six.moves.urllib.request import urlretrieve
import tarfile
import pickle
import sys


def get_file(fname,
             origin,
             untar=False,
             extract=False,
             archive_format='auto',
             cache_dir='data'):
    datadir = os.path.join(cache_dir)
    if not os.path.exists(datadir):
        os.makedirs(datadir)

    if untar:
        untar_fpath = os.path.join(datadir, fname)
        fpath = untar_fpath + '.tar.gz'
    else:
        fpath = os.path.join(datadir, fname)
    
    print(fpath)
    if not os.path.exists(fpath):
        print('Downloading data from', origin)

        error_msg = 'URL fetch failure on {}: {} -- {}'
        try:
            try:
                urlretrieve(origin, fpath)
            except URLError as e:
                raise Exception(error_msg.format(origin, e.errno, e.reason))
            except HTTPError as e:
                raise Exception(error_msg.format(origin, e.code, e.msg))
        except (Exception, KeyboardInterrupt) as e:
            if os.path.exists(fpath):
                os.remove(fpath)
            raise

    if untar:
        if not os.path.exists(untar_fpath):
            print('Extracting file.')
            with tarfile.open(fpath) as archive:
                archive.extractall(datadir)
        return untar_fpath

    if extract:
        _extract_archive(fpath, datadir, archive_format)

    return fpath

class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self
        
def to_var(tensor, cuda):
    """Wraps a Tensor in a Variable, optionally placing it on the GPU.

        Arguments:
            tensor: A Tensor object.
            cuda: A boolean flag indicating whether to use the GPU.

        Returns:
            A Variable object, on the GPU if cuda==True.
    """
    if cuda:
        return Variable(tensor.cuda())
    else:
        return Variable(tensor)


def create_dir_if_not_exists(directory):
    """Creates a directory if it doesn't already exist.
    """
    if not os.path.exists(directory):
        os.makedirs(directory)


def save_loss_plot(train_losses, val_losses, opts):
    """Saves a plot of the training and validation loss curves.
    """
    plt.figure()
    plt.plot(range(len(train_losses)), train_losses)
    plt.plot(range(len(val_losses)), val_losses)
    plt.title('BS={}, nhid={}'.format(opts.batch_size, opts.hidden_size), fontsize=20)
    plt.xlabel('Epochs', fontsize=16)
    plt.ylabel('Loss', fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.tight_layout()
    plt.savefig(os.path.join(opts.checkpoint_path, 'loss_plot.pdf'))
    plt.close()


def checkpoint(encoder, decoder, idx_dict, opts):
    """Saves the current encoder and decoder models, along with idx_dict, which
    contains the char_to_index and index_to_char mappings, and the start_token
    and end_token values.
    """
    with open(os.path.join(opts.checkpoint_path, 'encoder.pt'), 'wb') as f:
        torch.save(encoder, f)

    with open(os.path.join(opts.checkpoint_path, 'decoder.pt'), 'wb') as f:
        torch.save(decoder, f)

    with open(os.path.join(opts.checkpoint_path, 'idx_dict.pkl'), 'wb') as f:
        pkl.dump(idx_dict, f)

# %% [markdown]
# ## Data loader

# %%
def read_lines(filename):
    """Read a file and split it into lines.
    """
    lines = open(filename).read().strip().lower().split('\n')
    return lines


def read_pairs(filename):
    """Reads lines that consist of two words, separated by a space.

    Returns:
        source_words: A list of the first word in each line of the file.
        target_words: A list of the second word in each line of the file.
    """
    lines = read_lines(filename)
    source_words, target_words = [], []
    for line in lines:
        line = line.strip()
        if line:
            source, target = line.split()
            source_words.append(source)
            target_words.append(target)
    return source_words, target_words


def all_alpha_or_dash(s):
    """Helper function to check whether a string is alphabetic, allowing dashes '-'.
    """
    return all(c.isalpha() or c == '-' for c in s)


def filter_lines(lines):
    """Filters lines to consist of only alphabetic characters or dashes "-".
    """
    return [line for line in lines if all_alpha_or_dash(line)]


def load_data():
    """Loads (English, Pig-Latin) word pairs, and creates mappings from characters to indexes.
    """

    source_lines, target_lines = read_pairs('data/pig_latin_data.txt')

    # Filter lines
    source_lines = filter_lines(source_lines)
    target_lines = filter_lines(target_lines)

    all_characters = set(''.join(source_lines)) | set(''.join(target_lines))

    # Create a dictionary mapping each character to a unique index
    char_to_index = { char: index for (index, char) in enumerate(sorted(list(all_characters))) }

    # Add start and end tokens to the dictionary
    start_token = len(char_to_index)
    end_token = len(char_to_index) + 1
    char_to_index['SOS'] = start_token
    char_to_index['EOS'] = end_token

    # Create the inverse mapping, from indexes to characters (used to decode the model's predictions)
    index_to_char = { index: char for (char, index) in char_to_index.items() }

    # Store the final size of the vocabulary
    vocab_size = len(char_to_index)

    line_pairs = list(set(zip(source_lines, target_lines)))  # Python 3

    idx_dict = { 'char_to_index': char_to_index,
                 'index_to_char': index_to_char,
                 'start_token': start_token,
                 'end_token': end_token }

    return line_pairs, vocab_size, idx_dict


def create_dict(pairs):
    """Creates a mapping { (source_length, target_length): [list of (source, target) pairs]
    This is used to make batches: each batch consists of two parallel tensors, one containing
    all source indexes and the other containing all corresponding target indexes.
    Within a batch, all the source words are the same length, and all the target words are
    the same length.
    """
    unique_pairs = list(set(pairs))  # Find all unique (source, target) pairs

    d = defaultdict(list)
    for (s,t) in unique_pairs:
        d[(len(s), len(t))].append((s,t))

    return d

# %% [markdown]
# ## Training and evaluation code

# %%
def string_to_index_list(s, char_to_index, end_token):
    """Converts a sentence into a list of indexes (for each character).
    """
    return [char_to_index[char] for char in s] + [end_token]  # Adds the end token to each index list


def translate_sentence(sentence, encoder, decoder, idx_dict, opts):
    """Translates a sentence from English to Pig-Latin, by splitting the sentence into
    words (whitespace-separated), running the encoder-decoder model to translate each
    word independently, and then stitching the words back together with spaces between them.
    """
    if idx_dict is None:
      line_pairs, vocab_size, idx_dict = load_data()
    return ' '.join([translate(word, encoder, decoder, idx_dict, opts) for word in sentence.split()])


def translate(input_string, encoder, decoder, idx_dict, opts):
    """Translates a given string from English to Pig-Latin.
    """

    char_to_index = idx_dict['char_to_index']
    index_to_char = idx_dict['index_to_char']
    start_token = idx_dict['start_token']
    end_token = idx_dict['end_token']

    max_generated_chars = 20
    gen_string = ''

    indexes = string_to_index_list(input_string, char_to_index, end_token)
    indexes = to_var(torch.LongTensor(indexes).unsqueeze(0), opts.cuda)  # Unsqueeze to make it like BS = 1

    encoder_annotations, encoder_last_hidden = encoder(indexes)

    decoder_hidden = encoder_last_hidden
    decoder_input = to_var(torch.LongTensor([[start_token]]), opts.cuda)  # For BS = 1
    decoder_inputs = decoder_input

    for i in range(max_generated_chars):
      ## slow decoding, recompute everything at each time
      decoder_outputs, attention_weights = decoder(decoder_inputs, encoder_annotations, decoder_hidden)
      generated_words = F.softmax(decoder_outputs, dim=2).max(2)[1]
      ni = generated_words.cpu().numpy().reshape(-1)  # LongTensor of size 1
      ni = ni[-1] #latest output token

      decoder_inputs = torch.cat([decoder_input, generated_words], dim=1)
      
      if ni == end_token:
          break
      else:
          gen_string = "".join(
              [index_to_char[int(item)] 
               for item in generated_words.cpu().numpy().reshape(-1)])

    return gen_string


def visualize_attention(input_string, encoder, decoder, idx_dict, opts):
    """Generates a heatmap to show where attention is focused in each decoder step.
    """
    if idx_dict is None:
      line_pairs, vocab_size, idx_dict = load_data()
    char_to_index = idx_dict['char_to_index']
    index_to_char = idx_dict['index_to_char']
    start_token = idx_dict['start_token']
    end_token = idx_dict['end_token']

    max_generated_chars = 20
    gen_string = ''

    indexes = string_to_index_list(input_string, char_to_index, end_token)
    indexes = to_var(torch.LongTensor(indexes).unsqueeze(0), opts.cuda)  # Unsqueeze to make it like BS = 1

    encoder_annotations, encoder_hidden = encoder(indexes)

    decoder_hidden = encoder_hidden
    decoder_input = to_var(torch.LongTensor([[start_token]]), opts.cuda)  # For BS = 1
    decoder_inputs = decoder_input

    produced_end_token = False

    for i in range(max_generated_chars):
      ## slow decoding, recompute everything at each time
      decoder_outputs, attention_weights = decoder(decoder_inputs, encoder_annotations, decoder_hidden)
      generated_words = F.softmax(decoder_outputs, dim=2).max(2)[1]
      ni = generated_words.cpu().numpy().reshape(-1)  # LongTensor of size 1
      ni = ni[-1] #latest output token
      
      decoder_inputs = torch.cat([decoder_input, generated_words], dim=1)
      
      if ni == end_token:
          break
      else:
          gen_string = "".join(
              [index_to_char[int(item)] 
               for item in generated_words.cpu().numpy().reshape(-1)])
    
    if isinstance(attention_weights, tuple):
      ## transformer's attention mweights
      attention_weights, self_attention_weights = attention_weights
    
    all_attention_weights = attention_weights.data.cpu().numpy()
    
    for i in range(len(all_attention_weights)):
      attention_weights_matrix = all_attention_weights[i].squeeze()
      fig = plt.figure()
      ax = fig.add_subplot(111)
      cax = ax.matshow(attention_weights_matrix, cmap='bone')
      fig.colorbar(cax)

      # Set up axes
      ax.set_yticklabels([''] + list(input_string) + ['EOS'], rotation=90)
      ax.set_xticklabels([''] + list(gen_string) + (['EOS'] if produced_end_token else []))

      # Show label at every tick
      ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
      ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
      # Add title
      plt.xlabel('Attention weights to the source sentence in layer {}'.format(i+1))
      plt.tight_layout()
      plt.grid('off')
      plt.show()
      #plt.savefig(save)

      #plt.close(fig)

    return gen_string


def compute_loss(data_dict, encoder, decoder, idx_dict, criterion, optimizer, opts):
    """Train/Evaluate the model on a dataset.

    Arguments:
        data_dict: The validation/test word pairs, organized by source and target lengths.
        encoder: An encoder model to produce annotations for each step of the input sequence.
        decoder: A decoder model (with or without attention) to generate output tokens.
        idx_dict: Contains char-to-index and index-to-char mappings, and start & end token indexes.
        criterion: Used to compute the CrossEntropyLoss for each decoder output.
        optimizer: Train the weights if an optimizer is given. None if only evaluate the model. 
        opts: The command-line arguments.

    Returns:
        mean_loss: The average loss over all batches from data_dict.
    """
    start_token = idx_dict['start_token']
    end_token = idx_dict['end_token']
    char_to_index = idx_dict['char_to_index']

    losses = []
    for key in data_dict:
        input_strings, target_strings = zip(*data_dict[key])
        input_tensors = [torch.LongTensor(string_to_index_list(s, char_to_index, end_token)) for s in input_strings]
        target_tensors = [torch.LongTensor(string_to_index_list(s, char_to_index, end_token)) for s in target_strings]

        num_tensors = len(input_tensors)
        num_batches = int(np.ceil(num_tensors / float(opts.batch_size)))

        for i in range(num_batches):

            start = i * opts.batch_size
            end = start + opts.batch_size

            inputs = to_var(torch.stack(input_tensors[start:end]), opts.cuda)
            targets = to_var(torch.stack(target_tensors[start:end]), opts.cuda)

            # The batch size may be different in each epoch
            BS = inputs.size(0)

            encoder_annotations, encoder_hidden = encoder(inputs)

            # The last hidden state of the encoder becomes the first hidden state of the decoder
            decoder_hidden = encoder_hidden

            start_vector = torch.ones(BS).long().unsqueeze(1) * start_token  # BS x 1 --> 16x1  CHECKED
            decoder_input = to_var(start_vector, opts.cuda)  # BS x 1 --> 16x1  CHECKED

            loss = 0.0

            seq_len = targets.size(1)  # Gets seq_len from BS x seq_len

            decoder_inputs = torch.cat([decoder_input, targets[:, 0:-1]], dim=1)  # Gets decoder inputs by shifting the targets to the right 
            
            decoder_outputs, attention_weights = decoder(decoder_inputs, encoder_annotations, encoder_hidden)
            decoder_outputs_flatten = decoder_outputs.view(-1, decoder_outputs.size(2))
            targets_flatten = targets.view(-1)
            loss = criterion(decoder_outputs_flatten, targets_flatten)

            losses.append(loss.item())

            ## training if an optimizer is provided
            if optimizer:
              # Zero gradients
              optimizer.zero_grad()
              # Compute gradients
              loss.backward()
              # Update the parameters of the encoder and decoder
              optimizer.step()
              
    mean_loss = np.mean(losses)
    return mean_loss

  

def training_loop(train_dict, val_dict, idx_dict, encoder, decoder, criterion, optimizer, opts):
    """Runs the main training loop; evaluates the model on the val set every epoch.
        * Prints training and val loss each epoch.
        * Prints qualitative translation results each epoch using TEST_SENTENCE
        * Saves an attention map for TEST_WORD_ATTN each epoch

    Arguments:
        train_dict: The training word pairs, organized by source and target lengths.
        val_dict: The validation word pairs, organized by source and target lengths.
        idx_dict: Contains char-to-index and index-to-char mappings, and start & end token indexes.
        encoder: An encoder model to produce annotations for each step of the input sequence.
        decoder: A decoder model (with or without attention) to generate output tokens.
        criterion: Used to compute the CrossEntropyLoss for each decoder output.
        optimizer: Implements a step rule to update the parameters of the encoder and decoder.
        opts: The command-line arguments.
    """

    start_token = idx_dict['start_token']
    end_token = idx_dict['end_token']
    char_to_index = idx_dict['char_to_index']

    loss_log = open(os.path.join(opts.checkpoint_path, 'loss_log.txt'), 'w')

    best_val_loss = 1e6
    train_losses = []
    val_losses = []

    for epoch in range(opts.nepochs):

        optimizer.param_groups[0]['lr'] *= opts.lr_decay
        
        train_loss = compute_loss(train_dict, encoder, decoder, idx_dict, criterion, optimizer, opts)
        val_loss = compute_loss(val_dict, encoder, decoder, idx_dict, criterion, None, opts)

        if val_loss < best_val_loss:
            checkpoint(encoder, decoder, idx_dict, opts)

        gen_string = translate_sentence(TEST_SENTENCE, encoder, decoder, idx_dict, opts)
        print("Epoch: {:3d} | Train loss: {:.3f} | Val loss: {:.3f} | Gen: {:20s}".format(epoch, train_loss, val_loss, gen_string))

        loss_log.write('{} {} {}\n'.format(epoch, train_loss, val_loss))
        loss_log.flush()

        train_losses.append(train_loss)
        val_losses.append(val_loss)

        save_loss_plot(train_losses, val_losses, opts)


def print_data_stats(line_pairs, vocab_size, idx_dict):
    """Prints example word pairs, the number of data points, and the vocabulary.
    """
    print('=' * 80)
    print('Data Stats'.center(80))
    print('-' * 80)
    for pair in line_pairs[:5]:
        print(pair)
    print('Num unique word pairs: {}'.format(len(line_pairs)))
    print('Vocabulary: {}'.format(idx_dict['char_to_index'].keys()))
    print('Vocab size: {}'.format(vocab_size))
    print('=' * 80)


def train(opts):
    line_pairs, vocab_size, idx_dict = load_data()
    print_data_stats(line_pairs, vocab_size, idx_dict)

    # Split the line pairs into an 80% train and 20% val split
    num_lines = len(line_pairs)
    num_train = int(0.8 * num_lines)
    train_pairs, val_pairs = line_pairs[:num_train], line_pairs[num_train:]

    # Group the data by the lengths of the source and target words, to form batches
    train_dict = create_dict(train_pairs)
    val_dict = create_dict(val_pairs)

    ##########################################################################
    ### Setup: Create Encoder, Decoder, Learning Criterion, and Optimizers ###
    ##########################################################################
    encoder = GRUEncoder(vocab_size=vocab_size, 
                         hidden_size=opts.hidden_size, 
                         opts=opts)

    if opts.decoder_type == 'rnn':
        decoder = RNNDecoder(vocab_size=vocab_size, 
                             hidden_size=opts.hidden_size)
    elif opts.decoder_type == 'rnn_attention':
        decoder = RNNAttentionDecoder(vocab_size=vocab_size, 
                                      hidden_size=opts.hidden_size, 
                                      attention_type=opts.attention_type)
    elif opts.decoder_type == 'transformer':
        decoder = TransformerDecoder(vocab_size=vocab_size, 
                                     hidden_size=opts.hidden_size, 
                                     num_layers=opts.num_transformer_layers)
    else:
        raise NotImplementedError
        
    #### setup checkpoint path
    model_name = 'h{}-bs{}-{}'.format(opts.hidden_size, 
                                      opts.batch_size, 
                                      opts.decoder_type)
    opts.checkpoint_path = model_name
    create_dir_if_not_exists(opts.checkpoint_path)
    ####

    if opts.cuda:
        encoder.cuda()
        decoder.cuda()
        print("Moved models to GPU!")

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(list(encoder.parameters()) + list(decoder.parameters()), lr=opts.learning_rate)

    try:
        training_loop(train_dict, val_dict, idx_dict, encoder, decoder, criterion, optimizer, opts)
    except KeyboardInterrupt:
        print('Exiting early from training.')
        return encoder, decoder
      
    return encoder, decoder


def print_opts(opts):
    """Prints the values of all command-line arguments.
    """
    print('=' * 80)
    print('Opts'.center(80))
    print('-' * 80)
    for key in opts.__dict__:
        print('{:>30}: {:<30}'.format(key, opts.__dict__[key]).center(80))
    print('=' * 80)

# %% [markdown]
# # Your code for NMT models

# %% [markdown]
# ## GRU cell

# %%
class MyGRUCell(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(MyGRUCell, self).__init__()

        self.input_size = input_size
        self.hidden_size = hidden_size

        # ------------
        # FILL THIS IN
        # ------------
        ## Input linear layers
        self.Wiz = nn.Linear(input_size, hidden_size, bias=True)
        self.Wir = nn.Linear(input_size, hidden_size, bias=True)
        self.Wih = nn.Linear(input_size, hidden_size, bias=False)

        ## Hidden linear layers
        self.Whz = nn.Linear(hidden_size, hidden_size, bias=False)
        self.Whr = nn.Linear(hidden_size, hidden_size, bias=False)
        self.Whh = nn.Linear(hidden_size, hidden_size, bias=True)
        


    def forward(self, x, h_prev):
        """Forward pass of the GRU computation for one time step.

        Arguments
            x: batch_size x input_size
            h_prev: batch_size x hidden_size

        Returns:
            h_new: batch_size x hidden_size
        """

        # ------------
        # FILL THIS IN
        # ------------
        z = F.sigmoid(self.Wiz(x) + self.Whz(h_prev))
        r = F.sigmoid(self.Wir(x) + self.Whr(h_prev))
        g = F.tanh(self.Wih(x) + r*(self.Whh(h_prev)))
        h_new = (1-z)*g + z*h_prev
        return h_new

# %% [markdown]
# ### GRU encoder / decoder

# %%
class GRUEncoder(nn.Module):
    def __init__(self, vocab_size, hidden_size, opts):
        super(GRUEncoder, self).__init__()

        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.opts = opts

        self.embedding = nn.Embedding(vocab_size, hidden_size)
        self.gru = nn.GRUCell(hidden_size, hidden_size)

    def forward(self, inputs):
        """Forward pass of the encoder RNN.

        Arguments:
            inputs: Input token indexes across a batch for all time steps in the sequence. (batch_size x seq_len)

        Returns:
            annotations: The hidden states computed at each step of the input sequence. (batch_size x seq_len x hidden_size)
            hidden: The final hidden state of the encoder, for each sequence in a batch. (batch_size x hidden_size)
        """

        batch_size, seq_len = inputs.size()
        hidden = self.init_hidden(batch_size)

        encoded = self.embedding(inputs)  # batch_size x seq_len x hidden_size
        annotations = []

        for i in range(seq_len):
            x = encoded[:,i,:]  # Get the current time step, across the whole batch
            hidden = self.gru(x, hidden)
            annotations.append(hidden)

        annotations = torch.stack(annotations, dim=1)
        return annotations, hidden

    def init_hidden(self, bs):
        """Creates a tensor of zeros to represent the initial hidden states
        of a batch of sequences.

        Arguments:
            bs: The batch size for the initial hidden state.

        Returns:
            hidden: An initial hidden state of all zeros. (batch_size x hidden_size)
        """
        return to_var(torch.zeros(bs, self.hidden_size), self.opts.cuda)


class RNNDecoder(nn.Module):
    def __init__(self, vocab_size, hidden_size):
        super(RNNDecoder, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(vocab_size, hidden_size)
        self.rnn = nn.GRUCell(input_size=hidden_size, hidden_size=hidden_size)
        self.out = nn.Linear(hidden_size, vocab_size)

    def forward(self, inputs, annotations, hidden_init):
        """Forward pass of the non-attentional decoder RNN.

        Arguments:
            inputs: Input token indexes across a batch. (batch_size x seq_len)
            annotations: This is not used here. It just maintains consistency with the
                    interface used by the AttentionDecoder class.
            hidden_init: The hidden states from the last step of encoder, across a batch. (batch_size x hidden_size)

        Returns:
            output: Un-normalized scores for each token in the vocabulary, across a batch for all the decoding time steps. (batch_size x decoder_seq_len x vocab_size)
            None
        """        
        batch_size, seq_len = inputs.size()
        embed = self.embedding(inputs)  # batch_size x seq_len x hidden_size        

        hiddens = []
        h_prev = hidden_init
        for i in range(seq_len):
            x = embed[:,i,:]  # Get the current time step input tokens, across the whole batch
            h_prev = self.rnn(x, h_prev)  # batch_size x hidden_size
            hiddens.append(h_prev)

        hiddens = torch.stack(hiddens, dim=1) # batch_size x seq_len x hidden_size
        
        output = self.out(hiddens)  # batch_size x seq_len x vocab_size
        return output, None

# %%
class AdditiveAttention(nn.Module):
    def __init__(self, hidden_size):
        super(AdditiveAttention, self).__init__()

        self.hidden_size = hidden_size

        # A two layer fully-connected network
        # hidden_size*2 --> hidden_size, ReLU, hidden_size --> 1
        self.attention_network = nn.Sequential(
                                    nn.Linear(hidden_size*2, hidden_size),
                                    nn.ReLU(),
                                    nn.Linear(hidden_size, 1)
                                 )

        self.softmax = nn.Softmax(dim=1)

    def forward(self, queries, keys, values):
        """The forward pass of the additive attention mechanism.

        Arguments:
            queries: The current decoder hidden state. (batch_size x hidden_size)
            keys: The encoder hidden states for each step of the input sequence. (batch_size x seq_len x hidden_size)
            values: The encoder hidden states for each step of the input sequence. (batch_size x seq_len x hidden_size)

        Returns:
            context: weighted average of the values (batch_size x 1 x hidden_size)
            attention_weights: Normalized attention weights for each encoder hidden state. (batch_size x seq_len x 1)

            The attention_weights must be a softmax weighting over the seq_len annotations.
        """

        # ------------
        # FILL THIS IN
        # ------------
        batch_size = queries.shape[0]
        queries_exp = queries.view((queries.shape[0], -1, queries.shape[1]))
        expanded_queries = queries_exp.expand(keys.shape[0], keys.shape[1], keys.shape[2])
        concat_inputs = torch.cat((expanded_queries, keys), 2)
        unnormalized_attention = self.attention_network(concat_inputs)
        attention_weights = self.softmax(unnormalized_attention)
        context = torch.bmm(attention_weights.transpose(1, 2), values)
        return context, attention_weights
        
      

class ScaledDotAttention(nn.Module):
    def __init__(self, hidden_size):
        super(ScaledDotAttention, self).__init__()

        self.hidden_size = hidden_size

        self.Q = nn.Linear(hidden_size, hidden_size)
        self.K = nn.Linear(hidden_size, hidden_size)
        self.V = nn.Linear(hidden_size, hidden_size)
        self.softmax = nn.Softmax(dim=1)
        self.scaling_factor = torch.rsqrt(torch.tensor(self.hidden_size, dtype= torch.float))

    def forward(self, queries, keys, values):
        """The forward pass of the scaled dot attention mechanism.

        Arguments:
            queries: The current decoder hidden state, 2D or 3D tensor. (batch_size x (k) x hidden_size)
            keys: The encoder hidden states for each step of the input sequence. (batch_size x seq_len x hidden_size)
            values: The encoder hidden states for each step of the input sequence. (batch_size x seq_len x hidden_size)

        Returns:
            context: weighted average of the values (batch_size x k x hidden_size)
            attention_weights: Normalized attention weights for each encoder hidden state. (batch_size x seq_len x 1)

            The output must be a softmax weighting over the seq_len annotations.
        """

        # ------------
        # FILL THIS IN
        # ------------
        batch_size = values.shape[0]
        q = self.Q(queries)
        if len(q.shape) < 3 :
          q = q.unsqueeze(1)
        k = self.K(keys)
        v = self.V(values)
        unnormalized_attention = torch.bmm(k, q.transpose(1, 2))*(self.scaling_factor)
        attention_weights = self.softmax(unnormalized_attention)
        context = torch.bmm(attention_weights.transpose(1, 2), v)
        return context, attention_weights
        

      
      
class CausalScaledDotAttention(nn.Module):
    def __init__(self, hidden_size):
        super(CausalScaledDotAttention, self).__init__()

        self.hidden_size = hidden_size
        self.neg_inf = torch.tensor(-1e7)

        self.Q = nn.Linear(hidden_size, hidden_size)
        self.K = nn.Linear(hidden_size, hidden_size)
        self.V = nn.Linear(hidden_size, hidden_size)
        self.softmax = nn.Softmax(dim=1)
        self.scaling_factor = torch.rsqrt(torch.tensor(self.hidden_size, dtype= torch.float))

    def forward(self, queries, keys, values):
        """The forward pass of the scaled dot attention mechanism.

        Arguments:
            queries: The current decoder hidden state, 2D or 3D tensor. (batch_size x (k) x hidden_size)
            keys: The encoder hidden states for each step of the input sequence. (batch_size x seq_len x hidden_size)
            values: The encoder hidden states for each step of the input sequence. (batch_size x seq_len x hidden_size)

        Returns:
            context: weighted average of the values (batch_size x k x hidden_size)
            attention_weights: Normalized attention weights for each encoder hidden state. (batch_size x seq_len x k)

            The output must be a softmax weighting over the seq_len annotations.
        """

        # ------------
        # FILL THIS IN
        # ------------
        batch_size = values.shape[0]
        seq_len = keys.shape[1]
        q = self.Q(queries)
        seen = queries.shape[1]
        k = self.K(keys)
        v = self.V(values)
        unnormalized_attention = torch.bmm(k, q.transpose(1, 2))*(self.scaling_factor)
        mask = (torch.ones(unnormalized_attention.size()).triu().byte().cuda())

        unnormalized_attention = unnormalized_attention.masked_fill_(mask==0, self.neg_inf)
        attention_weights = self.softmax(unnormalized_attention)

        context = torch.bmm(attention_weights.transpose(1, 2), v)
        return context, attention_weights

# %% [markdown]
# ## Attention

# %% [markdown]
# ### Attention decoder

# %%
class RNNAttentionDecoder(nn.Module):
    def __init__(self, vocab_size, hidden_size, attention_type='scaled_dot'):
        super(RNNAttentionDecoder, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(vocab_size, hidden_size)

        self.rnn = MyGRUCell(input_size=hidden_size*2, hidden_size=hidden_size)
        if attention_type == 'additive':
          self.attention = AdditiveAttention(hidden_size=hidden_size)
        elif attention_type == 'scaled_dot':
          self.attention = ScaledDotAttention(hidden_size=hidden_size)
        
        self.out = nn.Linear(hidden_size, vocab_size)

        
    def forward(self, inputs, annotations, hidden_init):
        """Forward pass of the attention-based decoder RNN.

        Arguments:
            inputs: Input token indexes across a batch for all the time step. (batch_size x decoder_seq_len)
            annotations: The encoder hidden states for each step of the input.
                         sequence. (batch_size x seq_len x hidden_size)
            hidden_init: The final hidden states from the encoder, across a batch. (batch_size x hidden_size)

        Returns:
            output: Un-normalized scores for each token in the vocabulary, across a batch for all the decoding time steps. (batch_size x decoder_seq_len x vocab_size)
            attentions: The stacked attention weights applied to the encoder annotations (batch_size x encoder_seq_len x decoder_seq_len)
        """
        
        batch_size, seq_len = inputs.size()
        embed = self.embedding(inputs)  # batch_size x seq_len x hidden_size        

        hiddens = []
        attentions = []
        h_prev = hidden_init
        for i in range(seq_len):
            # ------------
            # FILL THIS IN
            # ------------
            embed_current = embed[:, i, :]
            context, attention_weights = self.attention(h_prev, annotations, annotations)

                
            embed_and_context = torch.cat((context.squeeze(1), embed_current.squeeze(1)), dim=1)
            h_prev = self.rnn(embed_and_context, h_prev)

            
            hiddens.append(h_prev)
            attentions.append(attention_weights)
        hiddens = torch.stack(hiddens, dim=1) # batch_size x seq_len x hidden_size
        attentions = torch.cat(attentions, dim=2) # batch_size x seq_len x seq_len
        
        output = self.out(hiddens)  # batch_size x seq_len x vocab_size
        

        return output, attentions

# %% [markdown]
# ### Transformer decoder

# %%
class TransformerDecoder(nn.Module):
    def __init__(self, vocab_size, hidden_size, num_layers):
        super(TransformerDecoder, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(vocab_size, hidden_size)        
        self.num_layers = num_layers
        
        self.self_attentions = nn.ModuleList([CausalScaledDotAttention(
                                    hidden_size=hidden_size, 
                                 ) for i in range(self.num_layers)])
        self.encoder_attentions = nn.ModuleList([ScaledDotAttention(
                                    hidden_size=hidden_size, 
                                 ) for i in range(self.num_layers)])
        self.attention_mlps = nn.ModuleList([nn.Sequential(
                                    nn.Linear(hidden_size, hidden_size),
                                    nn.ReLU(),
                                 ) for i in range(self.num_layers)])
        self.out = nn.Linear(hidden_size, vocab_size)

        
    def forward(self, inputs, annotations, hidden_init):
        """Forward pass of the attention-based decoder RNN.

        Arguments:
            inputs: Input token indexes across a batch for all the time step. (batch_size x decoder_seq_len)
            annotations: The encoder hidden states for each step of the input.
                         sequence. (batch_size x seq_len x hidden_size)
            hidden_init: Not used in the transformer decoder
        Returns:
            output: Un-normalized scores for each token in the vocabulary, across a batch for all the decoding time steps. (batch_size x decoder_seq_len x vocab_size)
            attentions: The stacked attention weights applied to the encoder annotations (batch_size x encoder_seq_len x decoder_seq_len)
        
        """
        
        batch_size, seq_len = inputs.size()
        embed = self.embedding(inputs)  # batch_size x seq_len x hidden_size        

        encoder_attention_weights_list = []
        self_attention_weights_list = []
        contexts = embed
        for i in range(self.num_layers):
          # ------------
          # FILL THIS IN
          # ------------
          new_contexts, self_attention_weights = self.self_attentions[i](contexts, contexts, contexts)
          residual_contexts = embed + new_contexts
          new_contexts, encoder_attention_weights = self.encoder_attentions[i](residual_contexts, 
                                                                               annotations, annotations)
          residual_contexts = residual_contexts + new_contexts
          new_contexts = self.attention_mlps[i](residual_contexts)
          contexts = new_contexts + residual_contexts

          
          encoder_attention_weights_list.append(encoder_attention_weights)
          self_attention_weights_list.append(self_attention_weights)
          
        output = self.out(contexts)
        encoder_attention_weights = torch.stack(encoder_attention_weights_list)#.squeeze(1)
        self_attention_weights = torch.stack(self_attention_weights_list)#.squeeze(1)
#         print("dec_s is " + str(inputs.shape[1]))
#         print("seq_len is " + str(annotations.shape[1]))
#         print("Output is of shape " + str(output.shape) + " and it should be batchx dec_s x vocab")
#         print("encoder_attn_weights is of shape " + str(encoder_attention_weights.shape) + " and it should be batch x enc_s x dec_s")
#         print('self_attn_weights is of shape' + str(self_attention_weights.shape) + " and it should be batch x enc_s x dec_s")
        
        
        return output, (encoder_attention_weights, self_attention_weights)

# %% [markdown]
# # Training

# %% [markdown]
# ## Download dataset

# %%
######################################################################
# Download Translation datasets
######################################################################
data_fpath = get_file(fname='pig_latin_data.txt', 
                         origin='http://www.cs.toronto.edu/~jba/pig_latin_data.txt', 
                         untar=False)
# Out:
# data/pig_latin_data.txt
# ('Downloading data from', 'http://www.cs.toronto.edu/~jba/pig_latin_data.txt')

# %% [markdown]
# ## RNN decoder

# %%
TEST_SENTENCE = 'the air conditioning is working'

args = AttrDict()
args_dict = {
              'cuda':True, 
              'nepochs':100, 
              'checkpoint_dir':"checkpoints", 
              'learning_rate':0.005, 
              'lr_decay':0.99,
              'batch_size':64, 
              'hidden_size':20, 
              'decoder_type': 'rnn', # options: rnn / rnn_attention / transformer
              'attention_type': 'scaled_dot',  # options: additive / scaled_dot
}
args.update(args_dict)

print_opts(args)
rnn_encoder, rnn_decoder = train(args)

translated = translate_sentence(TEST_SENTENCE, rnn_encoder, rnn_decoder, None, args)
print("source:\t\t{} \ntranslated:\t{}".format(TEST_SENTENCE, translated))
# Out:
# ================================================================================
#                                       Opts
# --------------------------------------------------------------------------------
#                             hidden_size: 20
#                           learning_rate: 0.005
#                              batch_size: 64
#                                 nepochs: 100
#                                    cuda: 1
#                          checkpoint_dir: checkpoints
#                            decoder_type: rnn
#                                lr_decay: 0.99
#                          attention_type: scaled_dot
# ================================================================================
# ================================================================================
#                                    Data Stats
# --------------------------------------------------------------------------------
# ('payment', 'aymentpay')
# ('ordination', 'ordinationway')
# ('amends', 'amendsway')
# ('principally', 'incipallypray')
# ('anybody', 'anybodyway')
# Num unique word pairs: 6387
# Vocabulary: ['EOS', '-', 'SOS', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z']
# Vocab size: 29
# ================================================================================
# Moved models to GPU!
# Epoch:   0 | Train loss: 2.388 | Val loss: 2.019 | Gen: eray eray ereray eray ereray
# Epoch:   1 | Train loss: 1.945 | Val loss: 1.830 | Gen: eray atay ontersay inglay onesssay
# Epoch:   2 | Train loss: 1.771 | Val loss: 1.722 | Gen: eray anteray ontersay ingsay ountay
# Epoch:   3 | Train loss: 1.662 | Val loss: 1.645 | Gen: eray arersay onessteray ingsay oustay
# Epoch:   4 | Train loss: 1.572 | Val loss: 1.576 | Gen: eray arerssay onenstssay issay oullay
# Epoch:   5 | Train loss: 1.495 | Val loss: 1.507 | Gen: eray arerssay oningstay issay oullay
# Epoch:   6 | Train loss: 1.433 | Val loss: 1.471 | Gen: eray areredway oningonsay issay onightay
# Epoch:   7 | Train loss: 1.380 | Val loss: 1.428 | Gen: eray arersay oningontay imay omponsay
# Epoch:   8 | Train loss: 1.330 | Val loss: 1.389 | Gen: ethay areredday onintingway imationsay onmangeray
# Epoch:   9 | Train loss: 1.294 | Val loss: 1.351 | Gen: estay ariedday oningtshay imay oundssay
# Epoch:  10 | Train loss: 1.261 | Val loss: 1.335 | Gen: ethay ariedday oningentsay imay oungoussay
# Epoch:  11 | Train loss: 1.234 | Val loss: 1.328 | Gen: estay ariedday onintingway impay oungonsay
# Epoch:  12 | Train loss: 1.213 | Val loss: 1.310 | Gen: estay aiechay onintingway imesay oussionsay
# Epoch:  13 | Train loss: 1.185 | Val loss: 1.286 | Gen: estay ariedday onintingway imay ondway-enteray
# Epoch:  14 | Train loss: 1.159 | Val loss: 1.269 | Gen: etay aiechay onintinglay imay ousencedray
# Epoch:  15 | Train loss: 1.129 | Val loss: 1.272 | Gen: estay aiechay onintingway imay onmernedsay
# Epoch:  16 | Train loss: 1.137 | Val loss: 1.240 | Gen: estay aiechay onintingway imay onsssionsay
# Epoch:  17 | Train loss: 1.102 | Val loss: 1.229 | Gen: etay aiechay onintinglay issay onssedray
# Epoch:  18 | Train loss: 1.076 | Val loss: 1.229 | Gen: estay aiechay onintingway issay onssedray
# Epoch:  19 | Train loss: 1.069 | Val loss: 1.207 | Gen: etay aieray onintingway issay onsserday
# Epoch:  20 | Train loss: 1.049 | Val loss: 1.210 | Gen: etay aiecray onintingway issay onscuserday
# Epoch:  21 | Train loss: 1.044 | Val loss: 1.208 | Gen: etay airedway onintingway issay onssedray
# Epoch:  22 | Train loss: 1.022 | Val loss: 1.189 | Gen: etay aiechay onintinglay issay onscursedway
# Epoch:  23 | Train loss: 1.020 | Val loss: 1.219 | Gen: estay airedway onintingway issay onscurssday
# Epoch:  24 | Train loss: 1.019 | Val loss: 1.192 | Gen: estay airedway onintinglay issay onsescoughtray
# Epoch:  25 | Train loss: 1.002 | Val loss: 1.204 | Gen: etay airedway onintingway issay onsescray
# Epoch:  26 | Train loss: 0.978 | Val loss: 1.170 | Gen: etay airedway onintinglay issay onsescedsay
# Epoch:  27 | Train loss: 0.966 | Val loss: 1.161 | Gen: estay airedway onintingway issay onsescray
# Epoch:  28 | Train loss: 0.946 | Val loss: 1.169 | Gen: estay airedway onintingway issay onsescray
# Epoch:  29 | Train loss: 0.949 | Val loss: 1.157 | Gen: estay airedway onintingway issay onsescray
# Epoch:  30 | Train loss: 0.933 | Val loss: 1.159 | Gen: etay airedway onintingway issay onsescray
# Epoch:  31 | Train loss: 0.919 | Val loss: 1.170 | Gen: etay airedway onintinglay issway onserssday
# Epoch:  32 | Train loss: 0.912 | Val loss: 1.125 | Gen: etay airway onintingway issay onsersedway
# Epoch:  33 | Train loss: 0.906 | Val loss: 1.130 | Gen: etay airway onintinglay ishay orndkingway
# Epoch:  34 | Train loss: 0.896 | Val loss: 1.128 | Gen: epay airway onintingway issay onserfedway
# Epoch:  35 | Train loss: 0.890 | Val loss: 1.165 | Gen: etay airedway onintinglay issway orndessssay
# Epoch:  36 | Train loss: 0.884 | Val loss: 1.108 | Gen: etay airedway onintingway isway orndesssay
# Epoch:  37 | Train loss: 0.883 | Val loss: 1.132 | Gen: epay airway onintinglay isshay onredfay
# Epoch:  38 | Train loss: 0.887 | Val loss: 1.147 | Gen: etay airway onintinglay isway onservedway
# Epoch:  39 | Train loss: 0.874 | Val loss: 1.131 | Gen: etay airedway onintinglay isway orfingscay
# Epoch:  40 | Train loss: 0.853 | Val loss: 1.084 | Gen: etay airway onintinglay isway ornesssday
# Epoch:  41 | Train loss: 0.835 | Val loss: 1.079 | Gen: etay airway onintingblay isway orndesssay
# Epoch:  42 | Train loss: 0.818 | Val loss: 1.080 | Gen: etay airway onintinglay isway onrivensway
# Epoch:  43 | Train loss: 0.824 | Val loss: 1.083 | Gen: etay airway onintinglay isway orndesssay
# Epoch:  44 | Train loss: 0.822 | Val loss: 1.066 | Gen: etay airway onintingblay isway orndesssay
# Epoch:  45 | Train loss: 0.816 | Val loss: 1.127 | Gen: etay airway onintinglay isway orndesssay
# Epoch:  46 | Train loss: 0.805 | Val loss: 1.058 | Gen: etay airway onintingblay isway orndesssay
# Epoch:  47 | Train loss: 0.799 | Val loss: 1.061 | Gen: etay airway onintingblay isway orndesssay
# Epoch:  48 | Train loss: 0.829 | Val loss: 1.087 | Gen: epay airway onintingway ishway ornesssday
# Epoch:  49 | Train loss: 0.840 | Val loss: 1.062 | Gen: etay airway onintingway isway orndessway
# Epoch:  50 | Train loss: 0.790 | Val loss: 1.033 | Gen: etay airway onintingblay isway orndessway
# Epoch:  51 | Train loss: 0.761 | Val loss: 1.034 | Gen: etay airway onintingbay isway orndessway
# Epoch:  52 | Train loss: 0.761 | Val loss: 1.038 | Gen: etay airway onintingblay isway orndesssay
# Epoch:  53 | Train loss: 0.747 | Val loss: 1.033 | Gen: etay airway onintingbay isway orndessway
# Epoch:  54 | Train loss: 0.759 | Val loss: 1.067 | Gen: eplay airway onintingcay isway orndesssay
# Epoch:  55 | Train loss: 0.758 | Val loss: 1.031 | Gen: etay airway onintingcay isway orndesssay
# Epoch:  56 | Train loss: 0.756 | Val loss: 1.034 | Gen: etay airway onintionsay isway orndesssay
# Epoch:  57 | Train loss: 0.735 | Val loss: 1.029 | Gen: etay airway onintionsay isway orndessway
# Epoch:  58 | Train loss: 0.732 | Val loss: 1.034 | Gen: etay airway onintingcay isway orndesssay
# Epoch:  59 | Train loss: 0.725 | Val loss: 1.019 | Gen: etay airway onintionsay isway orndessway
# Epoch:  60 | Train loss: 0.733 | Val loss: 1.076 | Gen: etay airway onintedtway isway orndesscay
# Epoch:  61 | Train loss: 0.789 | Val loss: 1.059 | Gen: etay airway onintionsray isway oringscay
# Epoch:  62 | Train loss: 0.750 | Val loss: 1.032 | Gen: etay airway onintionsway isway orkingway
# Epoch:  63 | Train loss: 0.709 | Val loss: 1.015 | Gen: etay airway onintionsay isway orkingway
# Epoch:  64 | Train loss: 0.705 | Val loss: 1.008 | Gen: etay airway onintionsay isway orkingway
# Epoch:  65 | Train loss: 0.691 | Val loss: 1.019 | Gen: etay airway onintionsay isway orkingway
# Epoch:  66 | Train loss: 0.687 | Val loss: 1.013 | Gen: etay airway onintionsay isway orkingway
# Epoch:  67 | Train loss: 0.689 | Val loss: 1.004 | Gen: etay airway onintededtay isway orkingway
# Epoch:  68 | Train loss: 0.686 | Val loss: 1.036 | Gen: etay airway onintionsay isway orndessway
# Epoch:  69 | Train loss: 0.709 | Val loss: 1.013 | Gen: etay airway onintioncay isway ornessday
# Epoch:  70 | Train loss: 0.717 | Val loss: 1.005 | Gen: etay airway onintedtedway isway orkingway
# Epoch:  71 | Train loss: 0.696 | Val loss: 0.995 | Gen: etay airway onintionsay isway orndefsay
# Epoch:  72 | Train loss: 0.687 | Val loss: 1.000 | Gen: etay airway onintionsay isway orkingway
# Epoch:  73 | Train loss: 0.730 | Val loss: 1.120 | Gen: etay aircay onditioncay isway orkingway
# Epoch:  74 | Train loss: 0.763 | Val loss: 1.019 | Gen: etay airway onintedday isway orkingway
# Epoch:  75 | Train loss: 0.675 | Val loss: 1.001 | Gen: etay airway oninteddsay isway orkingway
# Epoch:  76 | Train loss: 0.681 | Val loss: 0.998 | Gen: etay airway onintionsay isway orkingway
# Epoch:  77 | Train loss: 0.675 | Val loss: 0.978 | Gen: etay airway onintededway isway orkingway
# Epoch:  78 | Train loss: 0.656 | Val loss: 1.010 | Gen: etay airway onintededway isway orkingway
# Epoch:  79 | Train loss: 0.651 | Val loss: 0.982 | Gen: etay airway onintedtway isway orkingway
# Epoch:  80 | Train loss: 0.644 | Val loss: 0.993 | Gen: etay airway onintededtay isway orkingway
# Epoch:  81 | Train loss: 0.639 | Val loss: 0.981 | Gen: etay airway onintionsway isway orkingway
# Epoch:  82 | Train loss: 0.647 | Val loss: 1.033 | Gen: etay airway onintededtay isway ordifingway
# Epoch:  83 | Train loss: 0.651 | Val loss: 0.979 | Gen: etay airway onintedtway isway orkingway
# Epoch:  84 | Train loss: 0.644 | Val loss: 0.991 | Gen: etay airway onintededtay isway orkingway
# Epoch:  85 | Train loss: 0.756 | Val loss: 1.045 | Gen: ethay airway onintedceway isway orkingway
# Epoch:  86 | Train loss: 0.687 | Val loss: 0.989 | Gen: etay airway onintededway isway orkingway
# Epoch:  87 | Train loss: 0.646 | Val loss: 0.978 | Gen: etay airway onintedgedway isway orkingway
# Epoch:  88 | Train loss: 0.635 | Val loss: 0.983 | Gen: etay airway onintedgedway isway orkingway
# Epoch:  89 | Train loss: 0.626 | Val loss: 0.976 | Gen: etay airway onintededway isway orkingway
# Epoch:  90 | Train loss: 0.628 | Val loss: 0.973 | Gen: etay airway onintededway isway orkingway
# Epoch:  91 | Train loss: 0.623 | Val loss: 0.973 | Gen: etay airway onintededway isway orkingway
# Epoch:  92 | Train loss: 0.619 | Val loss: 0.992 | Gen: ethay airway onintededway isway orkingway
# Epoch:  93 | Train loss: 0.625 | Val loss: 0.969 | Gen: etay airway onintededway isway orkingway
# Epoch:  94 | Train loss: 0.641 | Val loss: 0.978 | Gen: etay airway onintededway isway orkingway
# Epoch:  95 | Train loss: 0.648 | Val loss: 0.984 | Gen: ethay airway onintionsay isway orkingway
# Epoch:  96 | Train loss: 0.637 | Val loss: 1.001 | Gen: ethay airway onintededway isway orkingway
# Epoch:  97 | Train loss: 0.620 | Val loss: 0.968 | Gen: etay airway onintededway isway orkingway
# Epoch:  98 | Train loss: 0.605 | Val loss: 0.984 | Gen: ethay airway onintedgedway isway orkingway
# Epoch:  99 | Train loss: 0.605 | Val loss: 0.971 | Gen: etay airway onintededtay isway orkingway
# source:		the air conditioning is working
# translated:	etay airway onintededtay isway orkingway

# %%
TEST_SENTENCE = 'consistently'
translated = translate_sentence(TEST_SENTENCE, rnn_encoder, rnn_decoder, None, args)
print("source:\t\t{} \ntranslated:\t{}".format(TEST_SENTENCE, translated))
# Out:
# source:		consistently
# translated:	onstitingcestay

# %% [markdown]
# ## RNN attention decoder

# %%
TEST_SENTENCE = 'the air conditioning is working'

args = AttrDict()
args_dict = {
              'cuda':True, 
              'nepochs':100, 
              'checkpoint_dir':"checkpoints", 
              'learning_rate':0.005, 
              'lr_decay':0.99,
              'batch_size':64, 
              'hidden_size':20, 
              'decoder_type': 'rnn_attention', # options: rnn / rnn_attention / transformer
              'attention_type': 'additive',  # options: additive / scaled_dot
}
args.update(args_dict)

print_opts(args)
rnn_attn_encoder, rnn_attn_decoder = train(args)

translated = translate_sentence(TEST_SENTENCE, rnn_attn_encoder, rnn_attn_decoder, None, args)
print("source:\t\t{} \ntranslated:\t{}".format(TEST_SENTENCE, translated))
# Out:
# ================================================================================
#                                       Opts
# --------------------------------------------------------------------------------
#                             hidden_size: 20
#                           learning_rate: 0.005
#                              batch_size: 64
#                                 nepochs: 100
#                                    cuda: 1
#                          checkpoint_dir: checkpoints
#                            decoder_type: rnn_attention
#                                lr_decay: 0.99
#                          attention_type: additive
# ================================================================================
# ================================================================================
#                                    Data Stats
# --------------------------------------------------------------------------------
# ('payment', 'aymentpay')
# ('ordination', 'ordinationway')
# ('amends', 'amendsway')
# ('principally', 'incipallypray')
# ('anybody', 'anybodyway')
# Num unique word pairs: 6387
# Vocabulary: ['EOS', '-', 'SOS', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z']
# Vocab size: 29
# ================================================================================
# Moved models to GPU!
# Epoch:   0 | Train loss: 2.323 | Val loss: 1.941 | Gen: eray ay oneneneneneray ay eneday
# Epoch:   1 | Train loss: 1.841 | Val loss: 1.686 | Gen: etay ay onsinglay ay onstay
# Epoch:   2 | Train loss: 1.593 | Val loss: 1.470 | Gen: esthay ay oncay istay onsinghay
# Epoch:   3 | Train loss: 1.356 | Val loss: 1.259 | Gen: esthay airay oncingay issay oustinghay
# Epoch:   4 | Train loss: 1.137 | Val loss: 1.095 | Gen: etay airay oncionway issay orkinghay
# Epoch:   5 | Train loss: 0.976 | Val loss: 0.904 | Gen: elay aimiray ondioningay issay orkingray
# Epoch:   6 | Train loss: 0.834 | Val loss: 0.823 | Gen: ethshay airray onditiongay isspay orkingray
# Epoch:   7 | Train loss: 0.707 | Val loss: 0.688 | Gen: elay airiway onditionningway issay orkingray
# Epoch:   8 | Train loss: 0.603 | Val loss: 0.615 | Gen: ehtay airfay onditioningway issay orkingway
# Epoch:   9 | Train loss: 0.594 | Val loss: 0.635 | Gen: ethay airway onditionway issay orkingway
# Epoch:  10 | Train loss: 0.566 | Val loss: 0.614 | Gen: ethay aircay onditioningay issay orkingray
# Epoch:  11 | Train loss: 0.507 | Val loss: 0.551 | Gen: ehthay airway onditioningway issay orkingray
# Epoch:  12 | Train loss: 0.469 | Val loss: 0.454 | Gen: ehthay airfay onditioningway issay orkingray
# Epoch:  13 | Train loss: 0.424 | Val loss: 0.485 | Gen: ehtay airfay onditioningway issay orkinghay
# Epoch:  14 | Train loss: 0.426 | Val loss: 0.475 | Gen: ethay airway onditioningray issay orkingray
# Epoch:  15 | Train loss: 0.416 | Val loss: 0.487 | Gen: ehthay airway onditiongray isfay orkingray
# Epoch:  16 | Train loss: 0.454 | Val loss: 0.443 | Gen: ehtay airway onditioningway isway orkinghay
# Epoch:  17 | Train loss: 0.434 | Val loss: 0.382 | Gen: ehtay airway onditioningway isway orkingray
# Epoch:  18 | Train loss: 0.306 | Val loss: 0.371 | Gen: ehtay airfay onditioningway isway orkingray
# Epoch:  19 | Train loss: 0.315 | Val loss: 0.325 | Gen: ehtay airfay onditioningway isway orkingray
# Epoch:  20 | Train loss: 0.316 | Val loss: 0.355 | Gen: ehay- airway onditioningway isway orkingray
# Epoch:  21 | Train loss: 0.283 | Val loss: 0.307 | Gen: ehtay airway onditioningway isway orkingray
# Epoch:  22 | Train loss: 0.241 | Val loss: 0.289 | Gen: ehay-y airway onditioningway isway orkingway
# Epoch:  23 | Train loss: 0.230 | Val loss: 0.270 | Gen: ehay airway onditioningway isway orkingway
# Epoch:  24 | Train loss: 0.209 | Val loss: 0.417 | Gen: ehay- airray onditioningway isway orkingway
# Epoch:  25 | Train loss: 0.353 | Val loss: 0.313 | Gen: ehay airway onditioningway isway orkingway
# Epoch:  26 | Train loss: 0.221 | Val loss: 0.265 | Gen: ehay- airray onditioningway isway orkingway
# Epoch:  27 | Train loss: 0.217 | Val loss: 0.236 | Gen: ehay- airway onditioningway isway orkingway
# Epoch:  28 | Train loss: 0.172 | Val loss: 0.232 | Gen: ehay airway onditioniggway isway orkingway
# Epoch:  29 | Train loss: 0.169 | Val loss: 0.216 | Gen: ehay airway onditioningway isway orkingway
# Epoch:  30 | Train loss: 0.194 | Val loss: 0.258 | Gen: ehay airway onpitioningray isway orkingway
# Epoch:  31 | Train loss: 0.195 | Val loss: 0.317 | Gen: ehay- airway onditioningway isway orkingway
# Epoch:  32 | Train loss: 0.213 | Val loss: 0.257 | Gen: ehay- airway onditoonggay isway orkingway
# Epoch:  33 | Train loss: 0.169 | Val loss: 0.219 | Gen: ehay- airway onditioningway isway orkingway
# Epoch:  34 | Train loss: 0.155 | Val loss: 0.265 | Gen: ehay- airway onditiongway isisay orkingway
# Epoch:  35 | Train loss: 0.156 | Val loss: 0.284 | Gen: ehay airway onditioningcay isway orkingway
# Epoch:  36 | Train loss: 0.160 | Val loss: 0.316 | Gen: ehtay airway onditiongway isway orkingway
# Epoch:  37 | Train loss: 0.130 | Val loss: 0.213 | Gen: ehay airway onditioningay isway orkingway
# Epoch:  38 | Train loss: 0.105 | Val loss: 0.281 | Gen: ethay airway onditiongway isway orkingway
# Epoch:  39 | Train loss: 0.113 | Val loss: 0.187 | Gen: etay- airway onditioningcay isway orkingway
# Epoch:  40 | Train loss: 0.091 | Val loss: 0.150 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  41 | Train loss: 0.076 | Val loss: 0.152 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  42 | Train loss: 0.064 | Val loss: 0.161 | Gen: ethay airway onditioningay isway orkingway
# Epoch:  43 | Train loss: 0.066 | Val loss: 0.144 | Gen: etlay airway onditioncingay isway orkingway
# Epoch:  44 | Train loss: 0.059 | Val loss: 0.146 | Gen: ethay airway onditionciglay isway orkingway
# Epoch:  45 | Train loss: 0.281 | Val loss: 0.714 | Gen: ehthay airray onditiongnay isway orkingway
# Epoch:  46 | Train loss: 0.263 | Val loss: 0.341 | Gen: ehay airway onditiongway isway orkingway
# Epoch:  47 | Train loss: 0.149 | Val loss: 0.289 | Gen: ethay airway onditiongway isway orkingway
# Epoch:  48 | Train loss: 0.095 | Val loss: 0.144 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  49 | Train loss: 0.062 | Val loss: 0.123 | Gen: ethay airway onditioningay isway orkingway
# Epoch:  50 | Train loss: 0.050 | Val loss: 0.124 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  51 | Train loss: 0.043 | Val loss: 0.119 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  52 | Train loss: 0.038 | Val loss: 0.116 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  53 | Train loss: 0.036 | Val loss: 0.146 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  54 | Train loss: 0.108 | Val loss: 0.180 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  55 | Train loss: 0.181 | Val loss: 0.148 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  56 | Train loss: 0.098 | Val loss: 0.218 | Gen: ethay airway onditioningray isway orkingway
# Epoch:  57 | Train loss: 0.063 | Val loss: 0.121 | Gen: ethay airway onditioningpay isway orkingway
# Epoch:  58 | Train loss: 0.040 | Val loss: 0.119 | Gen: ethay airway onditioncingay isway orkingway
# Epoch:  59 | Train loss: 0.036 | Val loss: 0.122 | Gen: ethaythethay airway onditioningcay isway orkingway
# Epoch:  60 | Train loss: 0.035 | Val loss: 0.113 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  61 | Train loss: 0.027 | Val loss: 0.103 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  62 | Train loss: 0.024 | Val loss: 0.105 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  63 | Train loss: 0.022 | Val loss: 0.102 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  64 | Train loss: 0.020 | Val loss: 0.101 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  65 | Train loss: 0.018 | Val loss: 0.102 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  66 | Train loss: 0.017 | Val loss: 0.100 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  67 | Train loss: 0.016 | Val loss: 0.102 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  68 | Train loss: 0.015 | Val loss: 0.100 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  69 | Train loss: 0.014 | Val loss: 0.105 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  70 | Train loss: 0.016 | Val loss: 0.117 | Gen: ethay airway onditioningcay isisay orkingway
# Epoch:  71 | Train loss: 0.200 | Val loss: 0.739 | Gen: eththtbay airway onditiontugly isisay orkinpway
# Epoch:  72 | Train loss: 0.419 | Val loss: 0.400 | Gen: etlay airray onditioningray isway orkingway
# Epoch:  73 | Train loss: 0.133 | Val loss: 0.180 | Gen: ethay airway onditioningnay isway orkingway
# Epoch:  74 | Train loss: 0.082 | Val loss: 0.156 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  75 | Train loss: 0.050 | Val loss: 0.131 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  76 | Train loss: 0.034 | Val loss: 0.131 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  77 | Train loss: 0.028 | Val loss: 0.128 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  78 | Train loss: 0.024 | Val loss: 0.118 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  79 | Train loss: 0.021 | Val loss: 0.118 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  80 | Train loss: 0.020 | Val loss: 0.113 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  81 | Train loss: 0.018 | Val loss: 0.115 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  82 | Train loss: 0.017 | Val loss: 0.109 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  83 | Train loss: 0.016 | Val loss: 0.112 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  84 | Train loss: 0.015 | Val loss: 0.107 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  85 | Train loss: 0.014 | Val loss: 0.110 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  86 | Train loss: 0.015 | Val loss: 0.109 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  87 | Train loss: 0.014 | Val loss: 0.111 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  88 | Train loss: 0.013 | Val loss: 0.111 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  89 | Train loss: 0.012 | Val loss: 0.103 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  90 | Train loss: 0.010 | Val loss: 0.108 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  91 | Train loss: 0.010 | Val loss: 0.110 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  92 | Train loss: 0.009 | Val loss: 0.109 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  93 | Train loss: 0.009 | Val loss: 0.110 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  94 | Train loss: 0.011 | Val loss: 0.109 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  95 | Train loss: 0.192 | Val loss: 0.239 | Gen: ehtay airway onditioningcay isway orkingway
# Epoch:  96 | Train loss: 0.071 | Val loss: 0.148 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  97 | Train loss: 0.029 | Val loss: 0.126 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  98 | Train loss: 0.021 | Val loss: 0.116 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  99 | Train loss: 0.015 | Val loss: 0.114 | Gen: ethay airway onditioningcay isway orkingway
# source:		the air conditioning is working
# translated:	ethay airway onditioningcay isway orkingway

# %%
TEST_SENTENCE = 'on my birthday weekened'
translated = translate_sentence(TEST_SENTENCE, rnn_attn_encoder, rnn_attn_decoder, None, args)
print("source:\t\t{} \ntranslated:\t{}".format(TEST_SENTENCE, translated))
# Out:
# source:		on my birthday weekened
# translated:	onway ymay irthdaybay eekenedway

# %% [markdown]
# ## Transformer

# %%
TEST_SENTENCE = 'the air conditioning is working'

args = AttrDict()
args_dict = {
              'cuda':True, 
              'nepochs':100, 
              'checkpoint_dir':"checkpoints", 
              'learning_rate':0.005, 
              'lr_decay':0.99,
              'batch_size':64, 
              'hidden_size':20, 
              'decoder_type': 'transformer', # options: rnn / rnn_attention / transformer
              'num_transformer_layers': 3,
}
args.update(args_dict)

print_opts(args)
transformer_encoder, transformer_decoder = train(args)

translated = translate_sentence(TEST_SENTENCE, transformer_encoder, transformer_decoder, None, args)
print("source:\t\t{} \ntranslated:\t{}".format(TEST_SENTENCE, translated))
# Out:
# ================================================================================
#                                       Opts
# --------------------------------------------------------------------------------
#                             hidden_size: 20
#                           learning_rate: 0.005
#                  num_transformer_layers: 3
#                              batch_size: 64
#                                 nepochs: 100
#                                    cuda: 1
#                          checkpoint_dir: checkpoints
#                            decoder_type: transformer
#                                lr_decay: 0.99
# ================================================================================
# ================================================================================
#                                    Data Stats
# --------------------------------------------------------------------------------
# ('payment', 'aymentpay')
# ('ordination', 'ordinationway')
# ('amends', 'amendsway')
# ('principally', 'incipallypray')
# ('anybody', 'anybodyway')
# Num unique word pairs: 6387
# Vocabulary: ['EOS', '-', 'SOS', 'a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n', 'q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z']
# Vocab size: 29
# ================================================================================
# Moved models to GPU!
# /usr/local/lib/python2.7/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type GRUEncoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python2.7/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type TransformerDecoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python2.7/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type CausalScaledDotAttention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python2.7/dist-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type ScaledDotAttention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch:   0 | Train loss: 2.276 | Val loss: 1.831 | Gen: elececey ay ongngngngnay insingnsingnsingngns ongngngngngngngngngn
# Epoch:   1 | Train loss: 1.713 | Val loss: 1.537 | Gen: ethay atay ondionay isisisisisisisisisis ongray
# Epoch:   2 | Train loss: 1.344 | Val loss: 1.196 | Gen: eththay airay ondionay isisisisisisisisisis oringray
# Epoch:   3 | Train loss: 1.016 | Val loss: 0.890 | Gen: ehehay airay oncay isay oray
# Epoch:   4 | Train loss: 0.830 | Val loss: 0.748 | Gen: etheway airay onayionay isway orkingray
# Epoch:   5 | Train loss: 0.665 | Val loss: 0.656 | Gen: ethay airay ondionay ispay orkingray
# Epoch:   6 | Train loss: 0.573 | Val loss: 0.589 | Gen: ethay airway ondingcay isway orkingway
# Epoch:   7 | Train loss: 0.488 | Val loss: 0.525 | Gen: ethay airway ondiongcay isispay orkingway
# Epoch:   8 | Train loss: 0.473 | Val loss: 0.508 | Gen: ethay airway ondionionionay issway orkingway
# Epoch:   9 | Train loss: 0.421 | Val loss: 0.501 | Gen: ethay airway ondininiongcay isway orkingway
# Epoch:  10 | Train loss: 0.447 | Val loss: 0.496 | Gen: ethay airway onkionay isway orkingway
# Epoch:  11 | Train loss: 0.420 | Val loss: 0.423 | Gen: ethay airway ondingcay isway orkingway
# Epoch:  12 | Train loss: 0.379 | Val loss: 0.358 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  13 | Train loss: 0.305 | Val loss: 0.397 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  14 | Train loss: 0.278 | Val loss: 0.371 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  15 | Train loss: 0.251 | Val loss: 0.320 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  16 | Train loss: 0.232 | Val loss: 0.315 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  17 | Train loss: 0.201 | Val loss: 0.285 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  18 | Train loss: 0.231 | Val loss: 0.300 | Gen: ewhay airway onditiongcay isway orkingway
# Epoch:  19 | Train loss: 0.264 | Val loss: 0.356 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  20 | Train loss: 0.243 | Val loss: 0.286 | Gen: ewhay airway onditiongcay isway orkingway
# Epoch:  21 | Train loss: 0.264 | Val loss: 0.307 | Gen: ethay airway onditiongcay issway orkingway
# Epoch:  22 | Train loss: 0.178 | Val loss: 0.265 | Gen: ethay airway onditingcay isway orkingway
# Epoch:  23 | Train loss: 0.151 | Val loss: 0.225 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  24 | Train loss: 0.142 | Val loss: 0.269 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  25 | Train loss: 0.130 | Val loss: 0.236 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  26 | Train loss: 0.134 | Val loss: 0.222 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  27 | Train loss: 0.153 | Val loss: 0.215 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  28 | Train loss: 0.113 | Val loss: 0.207 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  29 | Train loss: 0.133 | Val loss: 0.359 | Gen: ethay airway ondititioncayioncay issway orkingway
# Epoch:  30 | Train loss: 0.229 | Val loss: 0.309 | Gen: ethay airway onditingcay isway orkingway
# Epoch:  31 | Train loss: 0.170 | Val loss: 0.233 | Gen: ethay airway onditiongcay issway orkingway
# Epoch:  32 | Train loss: 0.116 | Val loss: 0.209 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  33 | Train loss: 0.111 | Val loss: 0.216 | Gen: ethay airway onditionlay issway orkingway
# Epoch:  34 | Train loss: 0.100 | Val loss: 0.225 | Gen: ethay airway onditingcay isway orkingway
# Epoch:  35 | Train loss: 0.102 | Val loss: 0.226 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  36 | Train loss: 0.087 | Val loss: 0.186 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  37 | Train loss: 0.069 | Val loss: 0.169 | Gen: ethay airway ondititionllay isway orkingway
# Epoch:  38 | Train loss: 0.110 | Val loss: 0.238 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  39 | Train loss: 0.106 | Val loss: 0.315 | Gen: ethay airway onditiongcay issway orkingway
# Epoch:  40 | Train loss: 0.103 | Val loss: 0.210 | Gen: ethay airway ondititingcay isway orkingway
# Epoch:  41 | Train loss: 0.132 | Val loss: 0.228 | Gen: ewhay airway onditiongcay issway orkingway
# Epoch:  42 | Train loss: 0.184 | Val loss: 0.307 | Gen: ethay airway onditioncay issway orkingway
# Epoch:  43 | Train loss: 0.136 | Val loss: 0.214 | Gen: ethay airway ondititingcay isway orkingway
# Epoch:  44 | Train loss: 0.091 | Val loss: 0.204 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  45 | Train loss: 0.057 | Val loss: 0.152 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  46 | Train loss: 0.065 | Val loss: 0.194 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  47 | Train loss: 0.058 | Val loss: 0.177 | Gen: ethay airway onditiongcay issway orkingway
# Epoch:  48 | Train loss: 0.059 | Val loss: 0.256 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  49 | Train loss: 0.076 | Val loss: 0.178 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  50 | Train loss: 0.056 | Val loss: 0.175 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  51 | Train loss: 0.074 | Val loss: 0.236 | Gen: ethay airway onditingcay isway orkingway
# Epoch:  52 | Train loss: 0.126 | Val loss: 0.190 | Gen: ethay airway onditiningcay isway orkingway
# Epoch:  53 | Train loss: 0.075 | Val loss: 0.145 | Gen: ethay airway onditiongcay issway orkingway
# Epoch:  54 | Train loss: 0.038 | Val loss: 0.147 | Gen: ethay airway onditiongcay issway orkingway
# Epoch:  55 | Train loss: 0.025 | Val loss: 0.155 | Gen: ethay airway onditioncay isway orkingway
# Epoch:  56 | Train loss: 0.019 | Val loss: 0.134 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  57 | Train loss: 0.017 | Val loss: 0.153 | Gen: ethay airway onditionloningcay isway orkingway
# Epoch:  58 | Train loss: 0.020 | Val loss: 0.153 | Gen: ethay airway onditionlgcay isway orkingway
# Epoch:  59 | Train loss: 0.023 | Val loss: 0.140 | Gen: ethay airway onditionlay isway orkingway
# Epoch:  60 | Train loss: 0.046 | Val loss: 0.234 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  61 | Train loss: 0.113 | Val loss: 0.199 | Gen: ethay airway onditinqulay isway orkingway
# Epoch:  62 | Train loss: 0.061 | Val loss: 0.162 | Gen: ethay airway onditingcay isway orkingway
# Epoch:  63 | Train loss: 0.046 | Val loss: 0.129 | Gen: ethay airway onditingcay isway orkingway
# Epoch:  64 | Train loss: 0.038 | Val loss: 0.126 | Gen: ethay airway onditincay isway orkingway
# Epoch:  65 | Train loss: 0.025 | Val loss: 0.134 | Gen: ethay airway onditingcay isway orkingway
# Epoch:  66 | Train loss: 0.048 | Val loss: 0.158 | Gen: ethay airway onditionlay isway orkingway
# Epoch:  67 | Train loss: 0.092 | Val loss: 0.158 | Gen: ethay airway onditingcay isway orkingway
# Epoch:  68 | Train loss: 0.047 | Val loss: 0.113 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  69 | Train loss: 0.046 | Val loss: 0.131 | Gen: ethay airway onditioncay isway orkingway
# Epoch:  70 | Train loss: 0.027 | Val loss: 0.108 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  71 | Train loss: 0.071 | Val loss: 0.155 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  72 | Train loss: 0.075 | Val loss: 0.236 | Gen: ethay airway ondititingcay isway ortingway
# Epoch:  73 | Train loss: 0.108 | Val loss: 0.163 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  74 | Train loss: 0.105 | Val loss: 0.191 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  75 | Train loss: 0.071 | Val loss: 0.146 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  76 | Train loss: 0.039 | Val loss: 0.138 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  77 | Train loss: 0.030 | Val loss: 0.119 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  78 | Train loss: 0.018 | Val loss: 0.124 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  79 | Train loss: 0.016 | Val loss: 0.123 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  80 | Train loss: 0.013 | Val loss: 0.120 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  81 | Train loss: 0.012 | Val loss: 0.117 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  82 | Train loss: 0.010 | Val loss: 0.116 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  83 | Train loss: 0.008 | Val loss: 0.121 | Gen: ethay airway onditioncay isway orkingway
# Epoch:  84 | Train loss: 0.008 | Val loss: 0.121 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  85 | Train loss: 0.010 | Val loss: 0.115 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  86 | Train loss: 0.016 | Val loss: 0.119 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  87 | Train loss: 0.016 | Val loss: 0.135 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  88 | Train loss: 0.015 | Val loss: 0.148 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  89 | Train loss: 0.030 | Val loss: 0.144 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  90 | Train loss: 0.062 | Val loss: 0.202 | Gen: ethay airway onditioncay isway orkingway
# Epoch:  91 | Train loss: 0.060 | Val loss: 0.109 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  92 | Train loss: 0.017 | Val loss: 0.104 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  93 | Train loss: 0.013 | Val loss: 0.123 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  94 | Train loss: 0.010 | Val loss: 0.135 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  95 | Train loss: 0.015 | Val loss: 0.126 | Gen: ethay airway onditioningcay isway orkingway
# Epoch:  96 | Train loss: 0.033 | Val loss: 0.120 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  97 | Train loss: 0.029 | Val loss: 0.113 | Gen: ethay airway onditiongcay isway orkingway
# Epoch:  98 | Train loss: 0.015 | Val loss: 0.108 | Gen: ethay airway onditioncay isway orkingway
# Epoch:  99 | Train loss: 0.018 | Val loss: 0.107 | Gen: ethay airway onditiongcay isway orkingway
# source:		the air conditioning is working
# translated:	ethay airway onditiongcay isway orkingway

# %%
TEST_SENTENCE = 'friends are always together consistently'
translated = translate_sentence(TEST_SENTENCE, transformer_encoder, transformer_decoder, None, args)
print("source:\t\t{} \ntranslated:\t{}".format(TEST_SENTENCE, translated))
# Out:
# source:		friends are always together consistently
# translated:	iendsfray areway alwaysway ogethertay onsistentlycay

# %% [markdown]
# # Attention visualization

# %%
TEST_WORD_ATTN = 'tray'

# %% [markdown]
# ## Visualize RNN attention map

# %%
visualize_attention(TEST_WORD_ATTN, rnn_attn_encoder, rnn_attn_decoder, None, args)
# Out:
# 'aytray'

# %% [markdown]
# ## Visualize transformer attention maps from all the transformer layers

# %%
visualize_attention(TEST_WORD_ATTN, transformer_encoder, transformer_decoder, None, args, )
# Out:
# 'aytray'
